# %% [markdown]
# <a href="https://colab.research.google.com/github/hanishkakotari-738/computer-vision/blob/main/cv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def show_comparison(original,blur3,blur11,blur50):
  plt.figure(figsize=(12,10))
  plt.subplot(2,2,1)
  plt.imshow(original,cmap='gray')
  plt.title("Original Grayscale Image")
  plt.axis('off')

  plt.subplot(2,2,2)
  plt.imshow(blur3,cmap='gray')
  plt.title("Average Filter (3x3)")
  plt.axis('off')



  plt.subplot(2,2,3)
  plt.imshow(blur11,cmap='gray')
  plt.title("Average Filter (11x11)")
  plt.axis('off')

  plt.subplot(2,2,4)
  plt.imshow(blur50,cmap='gray')
  plt.title("Average Filter (50x50)")
  plt.axis('off')

  plt.tight_layout()
  plt.show()

# %%
img=cv2.imread('/content/images (4).jpg',0)
if img is None:
  print("Error loading image")
else:
  kernel_3x3=np.ones((3,3),np.float32)/9

  kernel_11x11=np.ones((11,11),np.float32)/121
  kernel_50x50=np.ones((50,50),np.float32)/2500
  blur_3x3=cv2.filter2D(img,-1,kernel_3x3)

  blur_11x11=cv2.filter2D(img,-1,kernel_11x11)
  blur_50x50=cv2.filter2D(img,-1,kernel_50x50)
  show_comparison(img,blur_3x3,blur_11x11,blur_50x50)

# %%
kernel=np.ones((3,3))/9
k_s=3

# Corrected: Create filtered_img with integer dimensions based on the original image shape
# And replace manual convolution with cv2.filter2D
# Ensure 'img' is used instead of 'img1', as 'img' is the loaded image from previous cells
filtered_img = cv2.filter2D(img, -1, kernel)

# Corrected: Call show_comparison instead of show_plot
show_comparison(img, filtered_img, filtered_img, filtered_img)
